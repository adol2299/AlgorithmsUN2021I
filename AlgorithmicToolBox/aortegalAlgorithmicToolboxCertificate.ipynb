# %% [markdown]
# ##Certificado

# %% [markdown]
# ![Coursera%205VCN384DU662.pdf.png](data:image/png;base64,...)

# %% [markdown]
# **Enlace**
#
# [Linkedin](https://www.linkedin.com/in/andres-david-ortega-lobo-29953320b/)
