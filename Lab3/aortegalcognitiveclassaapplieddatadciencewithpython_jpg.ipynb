# %% [markdown]
# #LAB 3 cognitiveclass.ai Applied Data Science with Python

# %% [markdown]
# El link de Linkedin es: https://www.linkedin.com/in/andres-david-ortega-lobo-29953320b/

# %% [markdown]
# ##Data Analysis with Python
# ##![aortegalcognitiveclassaapplieddatadciencewithpython(1).PNG](data:image/png;base64,...)

# %% [markdown]
# ##Python 101 for Data Science
# ![aortegalcognitiveclassaapplieddatadciencewithpython(3).PNG](data:image/png;base64,...)

# %% [markdown]
# ##Data Visualization with Python
# ![aortegalcognitiveclassaapplieddatadciencewithpython(2).PNG](data:image/png;base64,...)
